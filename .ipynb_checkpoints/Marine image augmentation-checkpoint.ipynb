# %% [markdown]
# ##    classify as species type, then send to classifier to determine identity
# ###    Do I need to do object detection to separate the animal from the background
# ####   Can I manipulate/augment images as they are used by the model?
# ####   Convert iamges to grayscale?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import PIL
from PIL import Image
from matplotlib import image as img

# %%
# get image info using PILLOW

image=Image.open('000a8f2d5c316a.jpg')

# %%
print(image.size)
print(image.format)
print(image.mode)
image.show()
# Out:
# (3456, 2304)
# JPEG
# RGB

# %%
plt.imshow(image)

# %% [markdown]
# ## Resize Images retaining aspect ratio

# %%
image2=image.copy()
image2.thumbnail((256,256))
print(image.size)
print(image2.size)
# Out:
# (3456, 2304)
# (256, 171)

# %%
image22=image2.crop((0,0,256,256))

# %%
plt.imshow(image22)

# %% [markdown]
# ## Create Grayscale image

# %%
gs_image=image2.convert(mode='L')
gs_image.show()

# %%
plt.imshow(gs_image)

# %% [markdown]
# ## Flip images

# %%
image3= image2.transpose(Image.FLIP_TOP_BOTTOM)
plt.imshow(image3)

# %% [markdown]
# ## Rotate Images

# %%
image4=image2.rotate(15)
image5=image2.rotate(45)
image6=image2.rotate(65)
image7=image3.rotate(-15)
image8=image2.rotate(-45)
image9=image2.rotate(-65)
plt.imshow(image4)

# %% [markdown]
# ## Crop images

# %%
image10=image2.crop((0,0,200, 200))
image10.thumbnail((256,256))
plt.imshow(image10)

# %% [markdown]
# ## Normalize Pixel Values

# %%
from numpy import asarray
pixels=asarray(image2)
pixels=pixels.astype(float)
pixels/=255.0

# %%
pixels.min()
# Out:
# 0.11372549019607843

# %%
pixels.max()
# Out:
# 0.9019607843137255

# %%
plt.imshow(pixels)
